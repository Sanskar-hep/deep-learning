# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification
X,Y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_clusters_per_class=1, hypercube=False, class_sep=10, n_classes=2, random_state=41)
sns.scatterplot(x=X[:,0], y=X[:,1], hue=Y)
plt.show()

# %%
import numpy as np

def Perceptron(X, Y):
    X = np.insert(X, 0, 1, axis=1)     # Add bias column

    weights = np.ones(X.shape[1])      # Initialize weights
    lr = 0.1

    for i in range(1000):
        p1 = np.random.randint(0, X.shape[0])

        y_org = Y[p1]

        weight_cal = np.dot(weights, X[p1])

        y_pred = step(weight_cal)

        weights += lr * (y_org - y_pred) * X[p1]

    return weights[0], weights[1:]

# %%
intercept_, coeff_ = Perceptron(X, Y)

# %%
# plot the points, like you can calculate the slope of Ax+By+C=0
# so m = -(A/B)  and c = -(C/B)

m = -coeff_[0]/coeff_[1]
c = -intercept_/coeff_[1]

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + c

sns.scatterplot(x=X[:,0], y=X[:,1], hue=Y)
plt.plot(x_input, y_input)
plt.ylim(-5,5)
plt.show()

# %%
def step(z):
  if z>=0:
    return 1
  else:
    return 0
